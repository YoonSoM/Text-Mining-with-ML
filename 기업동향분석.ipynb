# %%
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm 
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
# Out:
# NanumGothic Eco

# %%
# !pip install chart_studio
# !pip install cufflinks
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.1 MB/s
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=d725c7eb32656537478450b2c74ae5b1364ceed71ffdc395ce5a398d4fb10208
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
df_kakao = pd.read_excel('./2020_3분기_카카오_실적발표.xlsx', sheet_name = 'IS(Con)' , header = 2)

df_kakao.head()
# Out:
#   Unnamed: 0 (단위: 백만원) Unnamed: 2          2017          1Q18          2Q18  \
# 0        NaN       매출액        NaN  1.972326e+12  5.554213e+11  5.889334e+11
# 1        NaN       NaN      플랫폼부문  8.247066e+11  2.322807e+11  2.510570e+11
# 2        NaN       NaN        톡비즈  2.581170e+11  8.854407e+10  9.758680e+10
# 3        NaN       NaN       포털비즈  5.029086e+11  1.217231e+11  1.283675e+11
# 4        NaN       NaN        신사업  6.368102e+10  2.201357e+10  2.510268e+10
#
#            3Q18          4Q18          2018          1Q19  ...          4Q19  \
# 0  5.992932e+11  6.733446e+11  2.416992e+12  7.063124e+11  ...  8.475887e+11
# 1  2.530100e+11  3.029669e+11  1.039315e+12  3.131139e+11  ...  4.440694e+11
# 2  1.071391e+11  1.278709e+11  4.211409e+11  1.269064e+11  ...  2.215725e+11
# 3  1.155454e+11  1.297934e+11  4.954293e+11  1.264162e+11  ...  1.341897e+11
# 4  3.032559e+10  4.530258e+10  1.227444e+11  5.979123e+10  ...  8.830723e+10
#
# ...

# %%
cols = list(df_kakao)
cols

q_cols  = [col for col in cols if str(col)[1] == 'Q']
q_cols

df_kakao[q_cols]
# Out:
#             1Q18          2Q18          3Q18          4Q18          1Q19  \
# 0   5.554213e+11  5.889334e+11  5.992932e+11  6.733446e+11  7.063124e+11
# 1   2.322807e+11  2.510570e+11  2.530100e+11  3.029669e+11  3.131139e+11
# 2   8.854407e+10  9.758680e+10  1.071391e+11  1.278709e+11  1.269064e+11
# 3   1.217231e+11  1.283675e+11  1.155454e+11  1.297934e+11  1.264162e+11
# 4   2.201357e+10  2.510268e+10  3.032559e+10  4.530258e+10  5.979123e+10
# 5   3.231406e+11  3.378764e+11  3.462831e+11  3.703777e+11  3.931986e+11
# 6   1.055907e+11  1.116384e+11  9.939728e+10  1.003336e+11  9.403274e+10
# 7   1.262692e+11  1.304611e+11  1.359913e+11  1.401288e+11  1.372282e+11
# 8   4.376658e+10  5.084501e+10  6.048244e+10  6.331281e+10  7.464676e+10
# 9   4.751417e+10  4.493187e+10  5.041207e+10  6.660247e+10  8.729084e+10
# 10           NaN           NaN           NaN           NaN           NaN
# 11  5.450196e+11  5.613433e+11  5.686290e+11  6.690516e+11  6.786490e+11
# ...

# %%
df_kakao
# Out:
#                                            Unnamed: 0 (단위: 백만원)  \
# 0                                                 NaN       매출액
# 1                                                 NaN       NaN
# 2                                                 NaN       NaN
# 3                                                 NaN       NaN
# 4                                                 NaN       NaN
# 5                                                 NaN       NaN
# 6                                                 NaN       NaN
# 7                                                 NaN       NaN
# 8                                                 NaN       NaN
# 9                                                 NaN       NaN
# 10                                                NaN       NaN
# 11                                                NaN       NaN
# 12                                                NaN       NaN
# 13                                                NaN       NaN
# ...

# %%
df_kakao['index'] = np.where(pd.notnull(df_kakao['(단위: 백만원)']) == True, df_kakao['(단위: 백만원)'], df_kakao['Unnamed: 2'])
df_kakao
# Out:
#                                            Unnamed: 0 (단위: 백만원)  \
# 0                                                 NaN       매출액
# 1                                                 NaN       NaN
# 2                                                 NaN       NaN
# 3                                                 NaN       NaN
# 4                                                 NaN       NaN
# 5                                                 NaN       NaN
# 6                                                 NaN       NaN
# 7                                                 NaN       NaN
# 8                                                 NaN       NaN
# 9                                                 NaN       NaN
# 10                                                NaN       NaN
# 11                                                NaN       NaN
# 12                                                NaN       NaN
# 13                                                NaN       NaN
# ...

# %%
df_kakao = df_kakao.set_index('index')
df_kakao
# Out:
#                                                       Unnamed: 0 (단위: 백만원)  \
# index
# 매출액                                                          NaN       매출액
# 플랫폼부문                                                        NaN       NaN
# 톡비즈                                                          NaN       NaN
# 포털비즈                                                         NaN       NaN
# 신사업                                                          NaN       NaN
# 콘텐츠부문                                                        NaN       NaN
# 게임 콘텐츠                                                       NaN       NaN
# 뮤직 콘텐츠                                                       NaN       NaN
# 유료 콘텐츠                                                       NaN       NaN
# IP비즈니스 기타                                                    NaN       NaN
# NaN                                                          NaN       NaN
# ...

# %%
df_kakao = df_kakao.drop(['Unnamed: 0', '(단위: 백만원)', 'Unnamed: 2'], axis=1)
df_kakao
# Out:
#                        2017          1Q18          2Q18          3Q18  \
# index
# 매출액            1.972326e+12  5.554213e+11  5.889334e+11  5.992932e+11
# 플랫폼부문          8.247066e+11  2.322807e+11  2.510570e+11  2.530100e+11
# 톡비즈            2.581170e+11  8.854407e+10  9.758680e+10  1.071391e+11
# 포털비즈           5.029086e+11  1.217231e+11  1.283675e+11  1.155454e+11
# 신사업            6.368102e+10  2.201357e+10  2.510268e+10  3.032559e+10
# 콘텐츠부문          1.147620e+12  3.231406e+11  3.378764e+11  3.462831e+11
# 게임 콘텐츠         3.420371e+11  1.055907e+11  1.116384e+11  9.939728e+10
# 뮤직 콘텐츠         4.785405e+11  1.262692e+11  1.304611e+11  1.359913e+11
# 유료 콘텐츠         1.269112e+11  4.376658e+10  5.084501e+10  6.048244e+10
# IP비즈니스 기타      2.001311e+11  4.751417e+10  4.493187e+10  5.041207e+10
# NaN                     NaN           NaN           NaN           NaN
# 영업비용           1.806947e+12  5.450196e+11  5.613433e+11  5.686290e+11
# ...

# %%
df_kakao = df_kakao[:-1]

df_kakao.dropna(axis=0, inplace=True)
df_kakao
# Out:
#                        2017          1Q18          2Q18          3Q18  \
# index
# 매출액            1.972326e+12  5.554213e+11  5.889334e+11  5.992932e+11
# 플랫폼부문          8.247066e+11  2.322807e+11  2.510570e+11  2.530100e+11
# 톡비즈            2.581170e+11  8.854407e+10  9.758680e+10  1.071391e+11
# 포털비즈           5.029086e+11  1.217231e+11  1.283675e+11  1.155454e+11
# 신사업            6.368102e+10  2.201357e+10  2.510268e+10  3.032559e+10
# 콘텐츠부문          1.147620e+12  3.231406e+11  3.378764e+11  3.462831e+11
# 게임 콘텐츠         3.420371e+11  1.055907e+11  1.116384e+11  9.939728e+10
# 뮤직 콘텐츠         4.785405e+11  1.262692e+11  1.304611e+11  1.359913e+11
# 유료 콘텐츠         1.269112e+11  4.376658e+10  5.084501e+10  6.048244e+10
# IP비즈니스 기타      2.001311e+11  4.751417e+10  4.493187e+10  5.041207e+10
# 영업비용           1.806947e+12  5.450196e+11  5.613433e+11  5.686290e+11
# 인건비            4.202619e+11  1.272584e+11  1.259213e+11  1.303490e+11
# ...

# %%
year = [2017, 2018, 2019, 2020]
qoq = df_kakao.columns[-4:-2]
yoy = df_kakao.columns[-2:]
quarters = df_kakao.columns[:-4].drop(year)

print('year :',year)
print('qoq :',qoq)
print('yoy :',yoy)
print('quarters :',quarters)
# Out:
# year : [2017, 2018, 2019, 2020]
# qoq : Index(['QoQ', 'QoQ(%)'], dtype='object')
# yoy : Index(['YoY', 'YoY(%)'], dtype='object')
# quarters : Index(['1Q18', '2Q18', '3Q18', '4Q18', '1Q19', '2Q19', '3Q19', '4Q19', '1Q20',
#        '2Q20', '3Q20'],
#       dtype='object')

# %%
df_kakao[quarters]
# Out:
#                        1Q18          2Q18          3Q18          4Q18  \
# index
# 매출액            5.554213e+11  5.889334e+11  5.992932e+11  6.733446e+11
# 플랫폼부문          2.322807e+11  2.510570e+11  2.530100e+11  3.029669e+11
# 톡비즈            8.854407e+10  9.758680e+10  1.071391e+11  1.278709e+11
# 포털비즈           1.217231e+11  1.283675e+11  1.155454e+11  1.297934e+11
# 신사업            2.201357e+10  2.510268e+10  3.032559e+10  4.530258e+10
# 콘텐츠부문          3.231406e+11  3.378764e+11  3.462831e+11  3.703777e+11
# 게임 콘텐츠         1.055907e+11  1.116384e+11  9.939728e+10  1.003336e+11
# 뮤직 콘텐츠         1.262692e+11  1.304611e+11  1.359913e+11  1.401288e+11
# 유료 콘텐츠         4.376658e+10  5.084501e+10  6.048244e+10  6.331281e+10
# IP비즈니스 기타      4.751417e+10  4.493187e+10  5.041207e+10  6.660247e+10
# 영업비용           5.450196e+11  5.613433e+11  5.686290e+11  6.690516e+11
# 인건비            1.272584e+11  1.259213e+11  1.303490e+11  1.583232e+11
# ...

# %%
df_kakao[quarters].loc[['매출액']].T
# Out:
# index           매출액
# 1Q18   5.554213e+11
# 2Q18   5.889334e+11
# 3Q18   5.992932e+11
# 4Q18   6.733446e+11
# 1Q19   7.063124e+11
# 2Q19   7.330353e+11
# 3Q19   7.831750e+11
# 4Q19   8.475887e+11
# 1Q20   8.683770e+11
# 2Q20   9.528531e+11
# 3Q20   1.100437e+12

# %%
df_kakao[quarters].loc['매출액']
# Out:
# 1Q18    5.554213e+11
# 2Q18    5.889334e+11
# 3Q18    5.992932e+11
# 4Q18    6.733446e+11
# 1Q19    7.063124e+11
# 2Q19    7.330353e+11
# 3Q19    7.831750e+11
# 4Q19    8.475887e+11
# 1Q20    8.683770e+11
# 2Q20    9.528531e+11
# 3Q20    1.100437e+12
# Name: 매출액, dtype: float64

# %%
data = pd.DataFrame(df_kakao[quarters].loc['매출액'])

display(data)
# Out:
#                매출액
# 1Q18  5.554213e+11
# 2Q18  5.889334e+11
# 3Q18  5.992932e+11
# 4Q18  6.733446e+11
# 1Q19  7.063124e+11
# 2Q19  7.330353e+11
# 3Q19  7.831750e+11
# 4Q19  8.475887e+11
# 1Q20  8.683770e+11
# 2Q20  9.528531e+11
# 3Q20  1.100437e+12

# %%
print('분기별 매출액 통계치 \n')
display(data.describe())

print('\n')
# Out:
# 분기별 매출액 통계치
#                 매출액
# count  1.100000e+01
# mean   7.644337e+11
# std    1.675975e+11
# min    5.554213e+11
# 25%    6.363189e+11
# 50%    7.330353e+11
# 75%    8.579829e+11
# max    1.100437e+12

# %%
fig = px.line(x = data.index, y = data['매출액'], labels=dict(x="분기", y="매출액", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')

display(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 부문별 매출액

# %%
pd.set_option('display.float_format', None)

data = df_kakao[quarters].loc[['플랫폼부문', '콘텐츠부문']]

print('분기별 매출액')
display(data)

print('\n')
# Out:
# 분기별 매출액
#                1Q18          2Q18          3Q18          4Q18          1Q19  \
# index
# 플랫폼부문  2.322807e+11  2.510570e+11  2.530100e+11  3.029669e+11  3.131139e+11
# 콘텐츠부문  3.231406e+11  3.378764e+11  3.462831e+11  3.703777e+11  3.931986e+11
#
#                2Q19          3Q19          4Q19          1Q20          2Q20  \
# index
# 플랫폼부문  3.268356e+11  3.507298e+11  4.440694e+11  4.418251e+11  4.926905e+11
# 콘텐츠부문  4.061997e+11  4.324452e+11  4.035192e+11  4.265520e+11  4.601626e+11
#
#                3Q20
# index
# 플랫폼부문  5.544009e+11
# 콘텐츠부문  5.460358e+11

# %%
print('카테고리별 각 분기 매출액 통계치 \n')
display(pd.DataFrame(data.loc['플랫폼부문'].describe()))
print('\n')
# Out:
# 카테고리별 각 분기 매출액 통계치
#               플랫폼부문
# count  1.100000e+01
# mean   3.602709e+11
# std    1.074361e+11
# min    2.322807e+11
# 25%    2.779885e+11
# 50%    3.268356e+11
# 75%    4.429472e+11
# max    5.544009e+11

# %%
data.reset_index()
# Out:
#    index          1Q18          2Q18          3Q18          4Q18  \
# 0  플랫폼부문  2.322807e+11  2.510570e+11  2.530100e+11  3.029669e+11
# 1  콘텐츠부문  3.231406e+11  3.378764e+11  3.462831e+11  3.703777e+11
#
#            1Q19          2Q19          3Q19          4Q19          1Q20  \
# 0  3.131139e+11  3.268356e+11  3.507298e+11  4.440694e+11  4.418251e+11
# 1  3.931986e+11  4.061997e+11  4.324452e+11  4.035192e+11  4.265520e+11
#
#            2Q20          3Q20
# 0  4.926905e+11  5.544009e+11
# 1  4.601626e+11  5.460358e+11

# %%
df_revenue_kakao = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters)
df_revenue_kakao.columns = ['category', 'quarter', 'revenue']
df_revenue_kakao
# Out:
#    category quarter       revenue
# 0     플랫폼부문    1Q18  2.322807e+11
# 1     콘텐츠부문    1Q18  3.231406e+11
# 2     플랫폼부문    2Q18  2.510570e+11
# 3     콘텐츠부문    2Q18  3.378764e+11
# 4     플랫폼부문    3Q18  2.530100e+11
# 5     콘텐츠부문    3Q18  3.462831e+11
# 6     플랫폼부문    4Q18  3.029669e+11
# 7     콘텐츠부문    4Q18  3.703777e+11
# 8     플랫폼부문    1Q19  3.131139e+11
# 9     콘텐츠부문    1Q19  3.931986e+11
# 10    플랫폼부문    2Q19  3.268356e+11
# 11    콘텐츠부문    2Q19  4.061997e+11
# 12    플랫폼부문    3Q19  3.507298e+11
# 13    콘텐츠부문    3Q19  4.324452e+11
# 14    플랫폼부문    4Q19  4.440694e+11
# 15    콘텐츠부문    4Q19  4.035192e+11
# 16    플랫폼부문    1Q20  4.418251e+11
# 17    콘텐츠부문    1Q20  4.265520e+11
# 18    플랫폼부문    2Q20  4.926905e+11
# 19    콘텐츠부문    2Q20  4.601626e+11
# 20    플랫폼부문    3Q20  5.544009e+11
# 21    콘텐츠부문    3Q20  5.460358e+11

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig1 = px.line(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'category', title='카테고리별 연 매출액', height = 500  , width = 1000)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'category',barmode = 'group' , title='분기별 각 카테고리 매출액',height = 500 , width = 1000)
fig2.show()

fig3 = px.bar(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'category', title='분기별 각 카테고리 매출액',height = 500 , width = 1000)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 세부 카테고리별 매출액

# %%
pd.set_option('display.float_format', None)
data = df_kakao[quarters].loc['톡비즈':'IP비즈니스 기타'].drop(['콘텐츠부문'], axis=0)

print('분기별 매출액')
display(data)

print('\n')

print('분기별 매출액 통계치 \n')
display(data.describe())
# Out:
# 분기별 매출액
#                    1Q18          2Q18          3Q18          4Q18  \
# index
# 톡비즈        8.854407e+10  9.758680e+10  1.071391e+11  1.278709e+11
# 포털비즈       1.217231e+11  1.283675e+11  1.155454e+11  1.297934e+11
# 신사업        2.201357e+10  2.510268e+10  3.032559e+10  4.530258e+10
# 게임 콘텐츠     1.055907e+11  1.116384e+11  9.939728e+10  1.003336e+11
# 뮤직 콘텐츠     1.262692e+11  1.304611e+11  1.359913e+11  1.401288e+11
# 유료 콘텐츠     4.376658e+10  5.084501e+10  6.048244e+10  6.331281e+10
# IP비즈니스 기타  4.751417e+10  4.493187e+10  5.041207e+10  6.660247e+10
#
#                    1Q19          2Q19          3Q19          4Q19  \
# index
# 톡비즈        1.269064e+11  1.389284e+11  1.624199e+11  2.215725e+11
# 포털비즈       1.264162e+11  1.369408e+11  1.260505e+11  1.341897e+11
# 신사업        5.979123e+10  5.096641e+10  6.225941e+10  8.830723e+10
# 게임 콘텐츠     9.403274e+10  9.840799e+10  9.899518e+10  1.059428e+11
# 뮤직 콘텐츠     1.372282e+11  1.446131e+11  1.514620e+11  1.532885e+11
# ...

# %%
df_revenue_kakao = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters, var_name = ['quarter'], value_name='revenue')
df_revenue_kakao.columns = ['sub_category', 'quarter', 'revenue']
print('변형된 데이터 프레임 형태')
display(df_revenue_kakao)
print('\n')
# Out:
# 변형된 데이터 프레임 형태
#    sub_category quarter       revenue
# 0           톡비즈    1Q18  8.854407e+10
# 1          포털비즈    1Q18  1.217231e+11
# 2           신사업    1Q18  2.201357e+10
# 3        게임 콘텐츠    1Q18  1.055907e+11
# 4        뮤직 콘텐츠    1Q18  1.262692e+11
# ..          ...     ...           ...
# 72          신사업    3Q20  1.488208e+11
# 73       게임 콘텐츠    3Q20  1.503529e+11
# 74       뮤직 콘텐츠    3Q20  1.557418e+11
# 75       유료 콘텐츠    3Q20  1.484027e+11
# 76    IP비즈니스 기타    3Q20  9.153843e+10
#
# [77 rows x 3 columns]

# %%
# 막대 그래프

from plotly.subplots import make_subplots
import plotly.graph_objects as go


fig1 = px.line(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'sub_category', title='카테고리별 연 매출액', height = 500  , width = 1200)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_revenue_kakao, x = 'sub_category', y = 'revenue', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 각 카테고리 매출액', color = 'sub_category', 
              height = 700 , width = 1200)
fig2.show()

fig3 = px.bar(df_revenue_kakao, x = 'quarter', y = 'revenue', facet_col = 'sub_category', facet_col_wrap = 2 ,  title='분기별 각 카테고리 매출액', color = 'sub_category', 
              height = 700 , width = 1200)
fig3.show()
# Out:
# 변형된 데이터 프레임 형태
#   sub_category quarter       revenue
# 0          톡비즈    1Q18  8.854407e+10
# 1         포털비즈    1Q18  1.217231e+11
# 2          신사업    1Q18  2.201357e+10
# 3       게임 콘텐츠    1Q18  1.055907e+11
# 4       뮤직 콘텐츠    1Q18  1.262692e+11
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="04c8da34-eeb6-4fa5-b6df-0988903714b6" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
df_revenue_kakao['year'] = df_revenue_kakao['quarter'].map(lambda x: x[-2:])
df_revenue_kakao
# Out:
#    sub_category quarter       revenue year
# 0           톡비즈    1Q18  8.854407e+10   18
# 1          포털비즈    1Q18  1.217231e+11   18
# 2           신사업    1Q18  2.201357e+10   18
# 3        게임 콘텐츠    1Q18  1.055907e+11   18
# 4        뮤직 콘텐츠    1Q18  1.262692e+11   18
# ..          ...     ...           ...  ...
# 72          신사업    3Q20  1.488208e+11   20
# 73       게임 콘텐츠    3Q20  1.503529e+11   20
# 74       뮤직 콘텐츠    3Q20  1.557418e+11   20
# 75       유료 콘텐츠    3Q20  1.484027e+11   20
# 76    IP비즈니스 기타    3Q20  9.153843e+10   20
#
# [77 rows x 4 columns]

# %%
x = float(input())
x
# Out:
# 123456
# 123456.0

# %%
len(str(x))-2
# Out:
# 6

# %%
def digit(x):
    cnt = 0
    while 1:
        x /= 10
        cnt += 1

        if x < 10:
            return cnt

# %%
cnt
# Out:
# 5

# %%
df_revenue_kakao['rev'] = df_revenue_kakao['revenue'].map(lambda x: len(str(x))-3)
df_revenue_kakao
# Out:
#    sub_category quarter       revenue year  rev
# 0           톡비즈    1Q18  8.854407e+10   18   10
# 1          포털비즈    1Q18  1.217231e+11   18   11
# 2           신사업    1Q18  2.201357e+10   18   10
# 3        게임 콘텐츠    1Q18  1.055907e+11   18   11
# 4        뮤직 콘텐츠    1Q18  1.262692e+11   18   11
# ..          ...     ...           ...  ...  ...
# 72          신사업    3Q20  1.488208e+11   20   11
# 73       게임 콘텐츠    3Q20  1.503529e+11   20   11
# 74       뮤직 콘텐츠    3Q20  1.557418e+11   20   11
# 75       유료 콘텐츠    3Q20  1.484027e+11   20   11
# 76    IP비즈니스 기타    3Q20  9.153843e+10   20   10
#
# [77 rows x 5 columns]

# %%
df_revenue_kakao['rev2'] = df_revenue_kakao['revenue'].map(digit)

# %%
df_revenue_kakao
# Out:
#    sub_category quarter       revenue year  rev  rev2
# 0           톡비즈    1Q18  8.854407e+10   18   10    10
# 1          포털비즈    1Q18  1.217231e+11   18   11    11
# 2           신사업    1Q18  2.201357e+10   18   10    10
# 3        게임 콘텐츠    1Q18  1.055907e+11   18   11    11
# 4        뮤직 콘텐츠    1Q18  1.262692e+11   18   11    11
# ..          ...     ...           ...  ...  ...   ...
# 72          신사업    3Q20  1.488208e+11   20   11    11
# 73       게임 콘텐츠    3Q20  1.503529e+11   20   11    11
# 74       뮤직 콘텐츠    3Q20  1.557418e+11   20   11    11
# 75       유료 콘텐츠    3Q20  1.484027e+11   20   11    11
# 76    IP비즈니스 기타    3Q20  9.153843e+10   20   10    10
#
# [77 rows x 6 columns]

# %%
df_revenue_kakao['category'] = df_revenue_kakao['sub_category'].map(lambda x: '플랫폼부문' if x in ['톡비즈', '포털비즈', '신사업'] else '콘텐츠부문') 


fig = px.bar(df_revenue_kakao, x = 'category', y = 'revenue', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 각 카테고리 매출액', color = 'sub_category',
              height = 700 , width = 1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f6d80cc8-7b70-4294-8d5d-f9d5e3c1e1e0" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f6d80cc8-7b70-4294-8d5d-f9d5e3c1e1e0")) {
#                     Plotly.newPlot(
#                         'f6d80cc8-7b70-4294-8d5d-f9d5e3c1e1e0',
# ...

# %% [markdown]
# #### 2. 영업이익

# %% [markdown]
# 전체 영업이익

# %%
from IPython.display import display
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format) 

data = pd.DataFrame(df_kakao[quarters].loc['영업이익'])

print('분기별 영업이익 \n')
display(data)
print('\n')

print('분기별 영업이익 통계치 \n')
display(data.describe())

print('\n')
fig = px.bar(x = data.index, y = data.values, labels=dict(x="분기", y="영업이익", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')
fig.show()
# Out:
# 분기별 영업이익
#                 영업이익
# 1Q18  10401711701.00
# 2Q18  27590056496.00
# 3Q18  30664121186.00
# 4Q18   4293000544.00
# 1Q19  27663385460.00
# 2Q19  40458579225.00
# 3Q19  59082342087.00
# 4Q19  79581915014.00
# 1Q20  88210720374.00
# 2Q20  97771189468.00
# 3Q20 120214821162.00
# 분기별 영업이익 통계치
#                  영업이익
# count           11.00
# mean   53266531156.09
# std    38256596853.10
# min     4293000544.00
# 25%    27626720978.00
# 50%    40458579225.00
# 75%    83896317694.00
# max   120214821162.00
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
profit_rate_kakao =  df_kakao[quarters].loc['영업이익']*100 / df_kakao[quarters].loc['매출액']

fig1 = px.line(profit_rate_kakao, x = profit_rate_kakao.index, y = profit_rate_kakao.values, title='분기별 영업이익률', labels=dict(x="분기", y="영업이익률(%)", color="Place"), height = 500, width = 700)
fig1.update_xaxes(type='category')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cedfd4f8-b049-425d-b13d-eb01a7c8a54f" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cedfd4f8-b049-425d-b13d-eb01a7c8a54f")) {
#                     Plotly.newPlot(
#                         'cedfd4f8-b049-425d-b13d-eb01a7c8a54f',
# ...

# %% [markdown]
# #### 3. 영업비용 변화

# %% [markdown]
# 전체 영업비용

# %%
from IPython.display import display
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format) 

data = pd.DataFrame(df_kakao[quarters].loc['영업비용'])

print('분기별 영업비용 \n')
display(data)
print('\n')

print('분기별 영업비용 통계치 \n')
display(data.describe())

print('\n')
fig = px.bar(x = data.index, y = data.values, labels=dict(x="분기", y="영업비용", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')

display(fig)
# Out:
# 분기별 영업비용
#                 영업비용
# 1Q18 545019587245.00
# 2Q18 561343320164.00
# 3Q18 568629044665.00
# 4Q18 669051598596.00
# 1Q19 678649032748.00
# 2Q19 692576702425.00
# 3Q19 724092649483.00
# 4Q19 768006758068.00
# 1Q20 780166311238.00
# 2Q20 855081865334.00
# 3Q20 980221855321.00
# 분기별 영업비용 통계치
#                  영업비용
# count           11.00
# mean  711167156844.27
# std   132214458365.25
# min   545019587245.00
# 25%   618840321630.50
# 50%   692576702425.00
# 75%   774086534653.00
# max   980221855321.00
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 영업비용 - 세부 카테고리

# %%
df_kakao[quarters].index
# Out:
# Index(['매출액', '플랫폼부문', '톡비즈', '포털비즈', '신사업', '콘텐츠부문', '게임 콘텐츠', '뮤직 콘텐츠',
#        '유료 콘텐츠', 'IP비즈니스 기타', '영업비용', '인건비', '매출연동비', '외주/인프라비', '마케팅비', '상각비',
#        '기타', '영업이익', '영업이익률(%)', '기타수익', '기타비용', '금융수익', '금융비용', '지분법손익',
#        '계속사업법인세차감전순이익', '계속사업법인세비용', '계속사업연결당기순이익', '중단사업순이익', '연결당기순이익',
#        '지배지분순이익', '비지배지분순이익', 'EBITDAR'],
#       dtype='object', name='index')

# %%
pd.set_option('display.float_format', None)

data = df_kakao[quarters].loc['인건비':'기타']

print('분기별 영업비용')
display(data)

print('\n')

print('분기별 영업비용 통계치 \n')
display(data.describe())
# Out:
# 분기별 영업비용
#                  1Q18          2Q18  ...          2Q20          3Q20
# index                                ...
# 인건비      1.272584e+11  1.259213e+11  ...  2.165258e+11  2.392910e+11
# 매출연동비    2.507200e+11  2.608024e+11  ...  4.094843e+11  4.637454e+11
# 외주/인프라비  6.811206e+10  7.374345e+10  ...  1.066113e+11  1.138675e+11
# 마케팅비     4.832434e+10  4.606166e+10  ...  3.854522e+10  7.625736e+10
# 상각비      3.144540e+10  3.394299e+10  ...  6.162059e+10  6.678115e+10
# 기타       1.915937e+10  2.087150e+10  ...  2.229468e+10  2.027948e+10
#
# [6 rows x 11 columns]
# 분기별 영업비용 통계치
#                1Q18          2Q18  ...          2Q20          3Q20
# count  6.000000e+00  6.000000e+00  ...  6.000000e+00  6.000000e+00
# mean   9.083660e+10  9.355722e+10  ...  1.425136e+11  1.633703e+11
# std    8.703779e+10  9.000430e+10  ...  1.482200e+11  1.648228e+11
# min    1.915937e+10  2.087150e+10  ...  2.229468e+10  2.027948e+10
# ...

# %%
df_cost_kakao = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters, var_name = ['quarter'], value_name='cost')
df_cost_kakao.columns = ['sub_category', 'quarter', 'cost']
print('변형된 데이터 프레임 형태')
display(df_cost_kakao.head())
print('\n')


from plotly.subplots import make_subplots
import plotly.graph_objects as go


fig1 = px.line(df_cost_kakao, x = 'quarter', y = 'cost', color = 'sub_category', title='카테고리별 연 영업비용', height = 500  , width = 1200)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_cost_kakao, x = 'sub_category', y = 'cost', facet_col = 'quarter', facet_col_wrap = 4,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig2.show()

fig3 = px.bar(df_cost_kakao, x = 'quarter', y = 'cost', facet_col = 'sub_category', facet_col_wrap = 3,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig3.show()
# Out:
# 변형된 데이터 프레임 형태
#   sub_category quarter          cost
# 0          인건비    1Q18  1.272584e+11
# 1        매출연동비    1Q18  2.507200e+11
# 2      외주/인프라비    1Q18  6.811206e+10
# 3         마케팅비    1Q18  4.832434e+10
# 4          상각비    1Q18  3.144540e+10
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="286a88fb-fbb3-439e-a66a-5121890cbbb0" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
fig = px.bar(df_cost_kakao, x = 'quarter', y = 'cost' ,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="799f1c94-2b4e-43c6-b62e-22e17527058f" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("799f1c94-2b4e-43c6-b62e-22e17527058f")) {
#                     Plotly.newPlot(
#                         '799f1c94-2b4e-43c6-b62e-22e17527058f',
# ...

# %% [markdown]
# #### 4. 고용분석

# %%
df_employees_kakao = pd.read_excel('./2020_3분기_카카오_실적발표.xlsx', sheet_name = 'Employees' , header = 3)
df_employees_kakao
# Out:
#                                           Unnamed: 0    1Q18  ...    QoQ     YoY
# 0                                                카카오  2529.0  ...  -45.0  -344.0
# 1                                           카카오 종속회사  3809.0  ...  522.0  2011.0
# 2                                                 합계  6338.0  ...  477.0  1667.0
# 3                                                NaN     NaN  ...    NaN     NaN
# 4  * 본사와 자회사의 겸직중인 직원의 경우 기존 본사 소속으로 분류되었으나, 2019...     NaN  ...    NaN     NaN
# 5  * 상기 종속회사는 인건비 산정에 포함된 종속회사를 나타낸 것으로 회계 기준상 연결...     NaN  ...    NaN     NaN
# 6  * 상기 숫자에는 정규직 및 계약직 사원이 포함되어 있으며, 어시스턴트와 인턴은 포...     NaN  ...    NaN     NaN
#
# [7 rows x 15 columns]

# %%
df_employees_kakao = df_employees_kakao[:3]

df_employees_kakao.drop(['4Q18.1', 'QoQ', 'YoY'], axis=1, inplace=True)


l  = ['category']
l.extend(df_employees_kakao.columns[1:])
df_employees_kakao.columns = l
df_employees_kakao
# Out:
#    category    1Q18    2Q18    3Q18  ...    4Q19    1Q20    2Q20    3Q20
# 0       카카오  2529.0  2533.0  2952.0  ...  2300.0  2366.0  2373.0  2328.0
# 1  카카오 종속회사  3809.0  4073.0  3985.0  ...  6301.0  6918.0  6975.0  7497.0
# 2        합계  6338.0  6606.0  6937.0  ...  8601.0  9284.0  9348.0  9825.0
#
# [3 rows x 12 columns]

# %%
df_employees_kakao.set_index('category').T.describe()
# Out:
# category          카카오     카카오 종속회사           합계
# count       11.000000    11.000000    11.000000
# mean      2548.636364  5504.454545  8053.090909
# std        202.626885  1306.521976  1165.944206
# min       2300.000000  3809.000000  6338.000000
# 25%       2369.500000  4286.500000  7106.000000
# 50%       2533.000000  5486.000000  8158.000000
# 75%       2640.500000  6609.500000  8942.500000
# max       2952.000000  7497.000000  9825.000000

# %%
df_melt_kakao = pd.melt(df_employees_kakao.iloc[:-1], id_vars = ['category'], value_vars = quarters, var_name = ['quarter'], value_name='employees')
df_melt_kakao.columns = ['category', 'quarter', 'employees']
print('변형된 데이터 프레임 형태')
display(df_melt_kakao.head())
print('\n')


from plotly.subplots import make_subplots
import plotly.graph_objects as go


fig1 = px.line(df_melt_kakao, x = 'quarter', y = 'employees', color = 'category', title='쿼터 별 직원 수', height = 500  , width = 1200)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_melt_kakao, x = 'quarter', y = 'employees',  title='쿼터별 직원수', color = 'category', 
              height = 700 , width = 1200)
fig2.show()
# Out:
# 변형된 데이터 프레임 형태
#    category quarter  employees
# 0       카카오    1Q18     2529.0
# 1  카카오 종속회사    1Q18     3809.0
# 2       카카오    2Q18     2533.0
# 3  카카오 종속회사    2Q18     4073.0
# 4       카카오    3Q18     2952.0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="001edf04-e0d6-430f-9647-f9d6ecd0fce8" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %% [markdown]
# ## 네이버_2020년도 4분기 실적발표 분석
# - 2020 4분기 네이버 실적발표: https://www.navercorp.com/investment/earningsRelease

# %%
df_naver = pd.read_excel('./Naver_Factsheet_4Q20_Kor.xlsx', header = 2)
df_naver
# Out:
#     Unnamed: 0  ...        QoQ
# 0          NaN  ...   0.111591
# 1          NaN  ...   0.084574
# 2          NaN  ...   0.043132
# 3          NaN  ...   0.218203
# 4          NaN  ...   0.110074
# 5          NaN  ...   0.155648
# 6          NaN  ...   0.208614
# 7          NaN  ...   0.122051
# 8          NaN  ...   0.112088
# 9          NaN  ...   0.002388
# 10         NaN  ...   0.170599
# 11         NaN  ...   0.090514
# 12         NaN  ...   0.180028
# 13         NaN  ...   0.109771
# 14         NaN  ...   1.803725
# 15         NaN  ...        NaN
# 16         NaN  ...   1.665451
# 17         NaN  ...  16.543770
# 18         NaN  ...   1.143866
# 19         NaN  ...  -0.153519
# 20         NaN  ...   9.618963
# 21         NaN  ...        NaN
# 22         NaN  ...   0.522173
# 23         NaN  ...   0.312950
# 24         NaN  ...   0.623031
# 25         NaN  ...        NaN
# 26         NaN  ...   0.594492
# 27         NaN  ...   0.693527
# 28         NaN  ...        NaN
# ...

# %%
df_naver.columns
# Out:
# Index(['Unnamed: 0', '(십억원)', '1Q19', '2Q19', '3Q19', '4Q19', '1Q20', '2Q20',
#        '3Q20', '4Q20', 'YoY', 'QoQ'],
#       dtype='object')

# %%
df_naver = df_naver.drop(['Unnamed: 0'], axis=1)

df_naver = df_naver[:-1]

df_naver.columns = ['index', '1Q19', '2Q19', '3Q19', '4Q19', '1Q20', '2Q20','3Q20', '4Q20', 'YoY', 'QoQ']

df_naver.set_index('index', inplace=True)
df_naver
# Out:
#                  1Q19         2Q19  ...       YoY        QoQ
# index                               ...
# 영업수익       992.816679  1088.548655  ...  0.282957   0.111591
# 서치플랫폼      626.261137   680.075410  ...  0.113029   0.084574
# 검색         501.881688   535.259285  ...  0.046524   0.043132
# 디스플레이      124.379449   144.816125  ...  0.349885   0.218203
# 커머스        177.443843   193.090935  ...  0.446398   0.110074
# 핀테크         87.314156    95.521770  ...  0.677583   0.155648
# 콘텐츠         60.090209    74.909549  ...  0.487884   0.208614
# 클라우드        41.707335    44.950991  ...  0.563025   0.122051
# 영업비용       702.909275   785.323318  ...  0.315693   0.112088
# 개발/운영비용    235.041165   253.391549  ...  0.073060   0.002388
# 파트너        310.550192   341.266186  ...  0.364039   0.170599
# 인프라         96.821540   100.872060  ...  0.346101   0.090514
# 마케팅         60.496378    89.793523  ...  0.782641   0.180028
# 영업이익       289.907404   303.225337  ...  0.175547   0.109771
# ...

# %%
qoq = ['QoQ']
yoy = ['YoY']
quarters = df_naver.columns[:-2]
quarters
# Out:
# Index(['1Q19', '2Q19', '3Q19', '4Q19', '1Q20', '2Q20', '3Q20', '4Q20'], dtype='object')

# %%
df_naver[quarters] *= 1000000000
df_naver
# Out:
#                    1Q19          2Q19  ...       YoY        QoQ
# index                                  ...
# 영업수익       9.928167e+11  1.088549e+12  ...  0.282957   0.111591
# 서치플랫폼      6.262611e+11  6.800754e+11  ...  0.113029   0.084574
# 검색         5.018817e+11  5.352593e+11  ...  0.046524   0.043132
# 디스플레이      1.243794e+11  1.448161e+11  ...  0.349885   0.218203
# 커머스        1.774438e+11  1.930909e+11  ...  0.446398   0.110074
# 핀테크        8.731416e+10  9.552177e+10  ...  0.677583   0.155648
# 콘텐츠        6.009021e+10  7.490955e+10  ...  0.487884   0.208614
# 클라우드       4.170733e+10  4.495099e+10  ...  0.563025   0.122051
# 영업비용       7.029093e+11  7.853233e+11  ...  0.315693   0.112088
# 개발/운영비용    2.350412e+11  2.533915e+11  ...  0.073060   0.002388
# 파트너        3.105502e+11  3.412662e+11  ...  0.364039   0.170599
# 인프라        9.682154e+10  1.008721e+11  ...  0.346101   0.090514
# 마케팅        6.049638e+10  8.979352e+10  ...  0.782641   0.180028
# ...

# %% [markdown]
# #### 1. 매출액(영업수익) 변화

# %% [markdown]
# 전체 매출액(영업수익)

# %%
from IPython.display import display
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format)

data = pd.DataFrame(df_naver[quarters].loc['영업수익'])

print('분기별 영업수익 \n')
display(data)
print('\n')

print('분기별 영업수익 통계치 \n')
display(data.describe())

print('\n')
fig = px.line(x = data.index, y = data.values, labels=dict(x="분기", y="영업수익", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')

display(fig)
# Out:
# 분기별 영업수익
#                  영업수익
# 1Q19  992816678672.00
# 2Q19 1088548654566.00
# 3Q19 1095855323057.00
# 4Q19 1179019011196.00
# 1Q20 1154694045031.00
# 2Q20 1276041988441.00
# 3Q20 1360779374259.00
# 4Q20 1512630492655.00
# 분기별 영업수익 통계치
#                   영업수익
# count             8.00
# mean  1207548195984.62
# std    168013473204.58
# min    992816678672.00
# 25%   1094028655934.25
# 50%   1166856528113.50
# 75%   1297226334895.50
# max   1512630492655.00
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# ...

# %% [markdown]
# 부문별 매출액

# %%
pd.set_option('display.float_format', None)

data = df_naver[quarters].loc[['서치플랫폼', '디스플레이']]

print('분기별 영업수익')
display(data)

print('\n')

print('카테고리별 각 분기 영업수익 통계치 \n')
display(pd.DataFrame(data.loc['서치플랫폼'].describe()))
print('\n')

display(pd.DataFrame(data.loc['디스플레이'].describe()))
# Out:
# 분기별 영업수익
#                1Q19          2Q19  ...          3Q20          4Q20
# index                              ...
# 서치플랫폼  6.262611e+11  6.800754e+11  ...  7.101101e+11  7.701669e+11
# 디스플레이  1.243794e+11  1.448161e+11  ...  1.680927e+11  2.047711e+11
#
# [2 rows x 8 columns]
# 카테고리별 각 분기 영업수익 통계치
#               서치플랫폼
# count  8.000000e+00
# mean   6.822156e+11
# std    4.446435e+10
# min    6.262611e+11
# 25%    6.534011e+11
# 50%    6.791158e+11
# 75%    6.964945e+11
# max    7.701669e+11
#               디스플레이
# count  8.000000e+00
# mean   1.503078e+11
# std    2.651172e+10
# min    1.243794e+11
# 25%    1.311041e+11
# 50%    1.476745e+11
# 75%    1.557946e+11
# max    2.047711e+11

# %%
df_revenue_kakao = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters, var_name = ['quarter'], value_name='revenue')
df_revenue_kakao.columns = ['category', 'quarter', 'revenue']

from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig1 = px.line(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'category', title='카테고리별 연 매출액', height = 500  , width = 1000)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_revenue_kakao, x = 'quarter', y = 'revenue', color = 'category',barmode = 'group' , title='분기별 각 카테고리 매출액',height = 500 , width = 1000)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ce17ec4-62ff-4614-a133-b3707e1960de" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ce17ec4-62ff-4614-a133-b3707e1960de")) {
#                     Plotly.newPlot(
#                         '1ce17ec4-62ff-4614-a133-b3707e1960de',
# ...

# %% [markdown]
# 세부 카테고리별 매출액

# %%
pd.set_option('display.float_format', None)

data = df_naver[quarters].loc['검색':'클라우드'].drop(['디스플레이'], axis=0)

print('분기별 매출액')
display(data)

print('\n')

print('분기별 매출액 통계치 \n')
display(data.describe())
# Out:
# 분기별 매출액
#                1Q19          2Q19  ...          3Q20          4Q20
# index                              ...
# 검색     5.018817e+11  5.352593e+11  ...  5.420174e+11  5.653958e+11
# 커머스    1.774438e+11  1.930909e+11  ...  2.854021e+11  3.168174e+11
# 핀테크    8.731416e+10  9.552177e+10  ...  1.740343e+11  2.011223e+11
# 콘텐츠    6.009021e+10  7.490955e+10  ...  1.149536e+11  1.389345e+11
# 클라우드   4.170733e+10  4.495099e+10  ...  7.627936e+10  8.558933e+10
#
# [5 rows x 8 columns]
# 분기별 매출액 통계치
#                1Q19          2Q19  ...          3Q20          4Q20
# count  5.000000e+00  5.000000e+00  ...  5.000000e+00  5.000000e+00
# mean   1.736874e+11  1.887465e+11  ...  2.385373e+11  2.615719e+11
# std    1.907282e+11  2.015049e+11  ...  1.871214e+11  1.904107e+11
# min    4.170733e+10  4.495099e+10  ...  7.627936e+10  8.558933e+10
# 25%    6.009021e+10  7.490955e+10  ...  1.149536e+11  1.389345e+11
# 50%    8.731416e+10  9.552177e+10  ...  1.740343e+11  2.011223e+11
# ...

# %%
df_revenue_naver = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters, var_name = ['quarter'], value_name='revenue')
df_revenue_naver.columns = ['sub_category', 'quarter', 'revenue']
print('변형된 데이터 프레임 형태')
display(df_revenue_naver.head())
print('\n')


from plotly.subplots import make_subplots
import plotly.graph_objects as go


fig1 = px.line(df_revenue_naver, x = 'quarter', y = 'revenue', color = 'sub_category', title='카테고리별 연 매출액', height = 500  , width = 1200)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_revenue_naver, x = 'sub_category', y = 'revenue', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 각 카테고리 매출액', color = 'sub_category', 
              height = 700 , width = 1200)
fig2.show()

fig3 = px.bar(df_revenue_naver, x = 'quarter', y = 'revenue', facet_col = 'sub_category', facet_col_wrap = 2 ,  title='분기별 각 카테고리 매출액', color = 'sub_category', 
              height = 700 , width = 1200)
fig3.show()
# Out:
# 변형된 데이터 프레임 형태
#   sub_category quarter       revenue
# 0           검색    1Q19  5.018817e+11
# 1          커머스    1Q19  1.774438e+11
# 2          핀테크    1Q19  8.731416e+10
# 3          콘텐츠    1Q19  6.009021e+10
# 4         클라우드    1Q19  4.170733e+10
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c2e4deb2-a8f7-408b-b16e-140e2d48bec9" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
df_revenue_naver['category'] = df_revenue_naver['sub_category'].map(lambda x: '서치플랫폼' if x == '검색' else '디스플레이') 


fig = px.bar(df_revenue_naver, x = 'category', y = 'revenue', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 각 카테고리 매출액', color = 'sub_category',
              height = 700 , width = 1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1289b7d7-b648-4e9a-b3dc-18609f7a44a3" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1289b7d7-b648-4e9a-b3dc-18609f7a44a3")) {
#                     Plotly.newPlot(
#                         '1289b7d7-b648-4e9a-b3dc-18609f7a44a3',
# ...

# %% [markdown]
# #### 2. 영업이익

# %% [markdown]
# 전체 영업이익

# %%
from IPython.display import display
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format) 

data = pd.DataFrame(df_naver[quarters].loc['영업이익'])

print('분기별 영업이익 \n')
display(data)
print('\n')

print('분기별 영업이익 통계치 \n')
display(data.describe())

print('\n')
fig = px.bar(x = data.index, y = data.values, labels=dict(x="분기", y="영업이익", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')
fig.show()
# Out:
# 분기별 영업이익
#                 영업이익
# 1Q19 289907403539.00
# 2Q19 303225336760.00
# 3Q19 286488937515.00
# 4Q19 275403766065.00
# 1Q20 291782450697.00
# 2Q20 308083164594.00
# 3Q20 291726798004.00
# 4Q20 323750043978.00
# 분기별 영업이익 통계치
#                  영업이익
# count            8.00
# mean  296295987644.00
# std    14906399872.71
# min   275403766065.00
# 25%   289052787033.00
# 50%   291754624350.50
# 75%   304439793718.50
# max   323750043978.00
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# ...

# %% [markdown]
# Naver Factsheet에는 영업이익률이 없음
#
# 영업이익률 = (영업이익/ 매출액) * 100 %

# %%
profit_rate_naver = pd.DataFrame(df_naver[quarters].loc['영업이익']*100 / df_naver[quarters].loc['영업수익'])
display(profit_rate_naver)

fig1 = px.line(profit_rate_naver, x = profit_rate_naver.index, y = profit_rate_naver.values, title='분기별 영업이익률', labels=dict(x="분기", y="영업이익률(%)", color="Place"), height = 500, width = 700)
fig1.update_xaxes(type='category')
fig1.show()
# Out:
#          0
# 1Q19 29.20
# 2Q19 27.86
# 3Q19 26.14
# 4Q19 23.36
# 1Q20 25.27
# 2Q20 24.14
# 3Q20 21.44
# 4Q20 21.40
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ddb441d0-d428-4283-b9d1-8b49821fd180" class="plotly-graph-div" style="height:500px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ddb441d0-d428-4283-b9d1-8b49821fd180")) {
#                     Plotly.newPlot(
# ...

# %% [markdown]
# #### 3. 영업비용 변화

# %% [markdown]
# 전체 영업비용

# %%
from IPython.display import display
import plotly.express as px

pd.set_option('display.float_format', '{:.2f}'.format) 

data = pd.DataFrame(df_naver[quarters].loc['영업비용'])

print('분기별 영업비용 \n')
display(data)
print('\n')

print('분기별 영업비용 통계치 \n')
display(data.describe())

print('\n')
fig = px.bar(x = data.index, y = data.values, labels=dict(x="분기", y="영업비용", color="Place"), height = 500, width = 700)
fig.update_xaxes(type='category')

display(fig)
# Out:
# 분기별 영업비용
#                  영업비용
# 1Q19  702909275133.00
# 2Q19  785323317806.00
# 3Q19  809366385542.00
# 4Q19  903615245131.00
# 1Q20  862911594334.00
# 2Q20  967958823847.00
# 3Q20 1069052576255.00
# 4Q20 1188880448677.00
# 분기별 영업비용 통계치
#                   영업비용
# count             8.00
# mean   911252208340.62
# std    159120241387.34
# min    702909275133.00
# 25%    803355618608.00
# 50%    883263419732.50
# 75%    993232261949.00
# max   1188880448677.00
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# ...

# %% [markdown]
# 영업비용 - 세부 카테고리

# %%
df_naver[quarters].index
# Out:
# Index(['영업수익', '서치플랫폼', '검색', '디스플레이', '커머스', '핀테크', '콘텐츠', '클라우드', '영업비용',
#        '개발/운영비용', '파트너', '인프라', '마케팅', '영업이익', '영업외수익', '기타이익', '금융수익',
#        '관계기업투자이익', '영업외비용', '기타손실', '금융비용', '관계기업투자손실', '법인세차감전순이익', '법인세비용',
#        '계속영업당기순이익', '중단영업손익', '당기순이익', '지배주주지분', '비지배주주지분', '기타포괄손익', '총 포괄이익',
#        '조정 EBITDA'],
#       dtype='object', name='index')

# %%
pd.set_option('display.float_format', None)

data = df_naver[quarters].loc['개발/운영비용':'마케팅']

print('분기별 영업비용')
display(data)

print('\n')

print('분기별 영업비용 통계치 \n')
display(data.describe())
# Out:
# 분기별 영업비용
#                  1Q19          2Q19  ...          3Q20          4Q20
# index                                ...
# 개발/운영비용  2.350412e+11  2.533915e+11  ...  3.116522e+11  3.123964e+11
# 파트너      3.105502e+11  3.412662e+11  ...  4.569598e+11  5.349167e+11
# 인프라      9.682154e+10  1.008721e+11  ...  1.447910e+11  1.578966e+11
# 마케팅      6.049638e+10  8.979352e+10  ...  1.556495e+11  1.836707e+11
#
# [4 rows x 8 columns]
# 분기별 영업비용 통계치
#                1Q19          2Q19  ...          3Q20          4Q20
# count  4.000000e+00  4.000000e+00  ...  4.000000e+00  4.000000e+00
# mean   1.757273e+11  1.963308e+11  ...  2.672631e+11  2.972201e+11
# std    1.171888e+11  1.220994e+11  ...  1.476620e+11  1.722735e+11
# min    6.049638e+10  8.979352e+10  ...  1.447910e+11  1.578966e+11
# 25%    8.774025e+10  9.810243e+10  ...  1.529349e+11  1.772272e+11
# 50%    1.659314e+11  1.771318e+11  ...  2.336509e+11  2.480336e+11
# ...

# %%
df_cost_naver = pd.melt(data.reset_index(), id_vars = ['index'], value_vars = quarters, var_name = ['quarter'], value_name='cost')
df_cost_naver.columns = ['sub_category', 'quarter', 'cost']
print('변형된 데이터 프레임 형태')
display(df_cost_naver.head())
print('\n')


from plotly.subplots import make_subplots
import plotly.graph_objects as go


fig1 = px.line(df_cost_naver, x = 'quarter', y = 'cost', color = 'sub_category', title='카테고리별 연 영업비용', height = 500  , width = 1200)
fig1.update_xaxes(type='category')
fig1.show()

fig2 = px.bar(df_cost_naver, x = 'sub_category', y = 'cost', facet_col = 'quarter', facet_col_wrap = 4,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig2.show()

fig3 = px.bar(df_cost_naver, x = 'quarter', y = 'cost', facet_col = 'sub_category', facet_col_wrap = 4,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig3.show()
# Out:
# 변형된 데이터 프레임 형태
#   sub_category quarter          cost
# 0      개발/운영비용    1Q19  2.350412e+11
# 1          파트너    1Q19  3.105502e+11
# 2          인프라    1Q19  9.682154e+10
# 3          마케팅    1Q19  6.049638e+10
# 4      개발/운영비용    2Q19  2.533915e+11
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="215a9fee-b9a6-41b1-9bdf-c5d5f0ad322c" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
fig = px.bar(df_cost_naver, x = 'quarter', y = 'cost' ,  title='분기별 각 카테고리 영업비용', color = 'sub_category', 
              height = 700 , width = 1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="89560d28-aed7-4f3c-a87a-05d11394f29a" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89560d28-aed7-4f3c-a87a-05d11394f29a")) {
#                     Plotly.newPlot(
#                         '89560d28-aed7-4f3c-a87a-05d11394f29a',
# ...

# %% [markdown]
# ## 3. 카카오 VS 네이버

# %%
quarters = ['1Q19', '2Q19', '3Q19', '4Q19', '1Q20', '2Q20', '3Q20']

df_naver_quarter = df_naver[quarters]
df_kakao_quarter = df_kakao[quarters]

# %%
df_naver_quarter.index
# Out:
# Index(['영업수익', '서치플랫폼', '검색', '디스플레이', '커머스', '핀테크', '콘텐츠', '클라우드', '영업비용',
#        '개발/운영비용', '파트너', '인프라', '마케팅', '영업이익', '영업외수익', '기타이익', '금융수익',
#        '관계기업투자이익', '영업외비용', '기타손실', '금융비용', '관계기업투자손실', '법인세차감전순이익', '법인세비용',
#        '계속영업당기순이익', '중단영업손익', '당기순이익', '지배주주지분', '비지배주주지분', '기타포괄손익', '총 포괄이익',
#        '조정 EBITDA'],
#       dtype='object', name='index')

# %%
df_kakao_quarter.index
# Out:
# Index(['매출액', '플랫폼부문', '톡비즈', '포털비즈', '신사업', '콘텐츠부문', '게임 콘텐츠', '뮤직 콘텐츠',
#        '유료 콘텐츠', 'IP비즈니스 기타', '영업비용', '인건비', '매출연동비', '외주/인프라비', '마케팅비', '상각비',
#        '기타', '영업이익', '영업이익률(%)', '기타수익', '기타비용', '금융수익', '금융비용', '지분법손익',
#        '계속사업법인세차감전순이익', '계속사업법인세비용', '계속사업연결당기순이익', '중단사업순이익', '연결당기순이익',
#        '지배지분순이익', '비지배지분순이익', 'EBITDAR'],
#       dtype='object', name='index')

# %%
df_naver_quarter.loc['영업이익률(%)'] = df_naver_quarter.loc['영업이익']*100 / df_naver_quarter.loc['영업수익']
df_kakao_quarter.loc['영업이익률(%)'] = df_kakao_quarter.loc['영업이익']*100 / df_kakao_quarter.loc['매출액']

df_naver_quarter = df_naver_quarter.loc[['영업수익', '서치플랫폼', '콘텐츠', '영업비용', '마케팅', '영업이익', '영업이익률(%)','당기순이익','조정 EBITDA']]
df_kakao_quarter = df_kakao_quarter.loc[['매출액', '플랫폼부문', '콘텐츠부문', '영업비용', '마케팅비', '영업이익', '영업이익률(%)','연결당기순이익','EBITDAR']]

df_naver_quarter.index = ['매출액', '플랫폼부문', '콘텐츠부문', '영업비용', '마케팅비', '영업이익', '영업이익률(%)','당기순이익','조정 EBITDA']
df_kakao_quarter.index = ['매출액', '플랫폼부문', '콘텐츠부문', '영업비용', '마케팅비', '영업이익', '영업이익률(%)','당기순이익','조정 EBITDA']


print('네이버 재무제표')
display(df_naver_quarter)

print('카카오 재무제표')
display(df_kakao_quarter)
# Out:
# 네이버 재무제표
#                    1Q19          2Q19  ...          2Q20          3Q20
# 매출액        9.928167e+11  1.088549e+12  ...  1.276042e+12  1.360779e+12
# 플랫폼부문      6.262611e+11  6.800754e+11  ...  6.781561e+11  7.101101e+11
# 콘텐츠부문      6.009021e+10  7.490955e+10  ...  1.129368e+11  1.149536e+11
# 영업비용       7.029093e+11  7.853233e+11  ...  9.679588e+11  1.069053e+12
# 마케팅비       6.049638e+10  8.979352e+10  ...  1.146820e+11  1.556495e+11
# 영업이익       2.899074e+11  3.032253e+11  ...  3.080832e+11  2.917268e+11
# 영업이익률(%)   2.920050e+01  2.785593e+01  ...  2.414365e+01  2.143821e+01
# 당기순이익      8.758590e+10  2.775685e+10  ...  9.068220e+10  2.353430e+11
# 조정 EBITDA  3.376045e+11  3.580729e+11  ...  4.019139e+11  3.898027e+11
#
# [9 rows x 7 columns]
# 카카오 재무제표
#                    1Q19          2Q19  ...          2Q20          3Q20
# 매출액        7.063124e+11  7.330353e+11  ...  9.528531e+11  1.100437e+12
# 플랫폼부문      3.131139e+11  3.268356e+11  ...  4.926905e+11  5.544009e+11
# ...

# %%
df_kakao_quarter['회사명'] = '카카오' 
df_kakao_quarter = df_kakao_quarter.reset_index() 

df_naver_quarter['회사명'] = '네이버'
df_naver_quarter = df_naver_quarter.reset_index()

df_compare = pd.concat([df_naver_quarter, df_kakao_quarter], axis = 0, ignore_index=True) 
df_compare
# Out:
#         index          1Q19          2Q19  ...          2Q20          3Q20  회사명
# 0         매출액  9.928167e+11  1.088549e+12  ...  1.276042e+12  1.360779e+12  네이버
# 1       플랫폼부문  6.262611e+11  6.800754e+11  ...  6.781561e+11  7.101101e+11  네이버
# 2       콘텐츠부문  6.009021e+10  7.490955e+10  ...  1.129368e+11  1.149536e+11  네이버
# 3        영업비용  7.029093e+11  7.853233e+11  ...  9.679588e+11  1.069053e+12  네이버
# 4        마케팅비  6.049638e+10  8.979352e+10  ...  1.146820e+11  1.556495e+11  네이버
# 5        영업이익  2.899074e+11  3.032253e+11  ...  3.080832e+11  2.917268e+11  네이버
# 6    영업이익률(%)  2.920050e+01  2.785593e+01  ...  2.414365e+01  2.143821e+01  네이버
# 7       당기순이익  8.758590e+10  2.775685e+10  ...  9.068220e+10  2.353430e+11  네이버
# 8   조정 EBITDA  3.376045e+11  3.580729e+11  ...  4.019139e+11  3.898027e+11  네이버
# 9         매출액  7.063124e+11  7.330353e+11  ...  9.528531e+11  1.100437e+12  카카오
# 10      플랫폼부문  3.131139e+11  3.268356e+11  ...  4.926905e+11  5.544009e+11  카카오
# ...

# %%
df_compare = pd.melt(df_compare, id_vars=['index', '회사명'],value_vars=quarters, var_name=['quarter'], value_name = 'value')
df_compare.set_index('index', inplace = True)

df_compare
# Out:
#            회사명 quarter         value
# index
# 매출액        네이버    1Q19  9.928167e+11
# 플랫폼부문      네이버    1Q19  6.262611e+11
# 콘텐츠부문      네이버    1Q19  6.009021e+10
# 영업비용       네이버    1Q19  7.029093e+11
# 마케팅비       네이버    1Q19  6.049638e+10
# ...        ...     ...           ...
# 마케팅비       카카오    3Q20  7.625736e+10
# 영업이익       카카오    3Q20  1.202148e+11
# 영업이익률(%)   카카오    3Q20  1.092428e+01
# 당기순이익      카카오    3Q20  1.437280e+11
# 조정 EBITDA  카카오    3Q20  1.852211e+11
#
# [126 rows x 3 columns]

# %%
df_compare.loc['매출액']
# Out:
#        회사명 quarter         value
# index
# 매출액    네이버    1Q19  9.928167e+11
# 매출액    카카오    1Q19  7.063124e+11
# 매출액    네이버    2Q19  1.088549e+12
# 매출액    카카오    2Q19  7.330353e+11
# 매출액    네이버    3Q19  1.095855e+12
# 매출액    카카오    3Q19  7.831750e+11
# 매출액    네이버    4Q19  1.179019e+12
# 매출액    카카오    4Q19  8.475887e+11
# 매출액    네이버    1Q20  1.154694e+12
# 매출액    카카오    1Q20  8.683770e+11
# 매출액    네이버    2Q20  1.276042e+12
# 매출액    카카오    2Q20  9.528531e+11
# 매출액    네이버    3Q20  1.360779e+12
# 매출액    카카오    3Q20  1.100437e+12

# %% [markdown]
# #### 매출액 비교

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig1 = px.line(df_compare.loc['매출액'], x = 'quarter', y = 'value', color = '회사명', title='분기별 매출액', height = 500  , width = 1000,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

fig2 = px.bar(df_compare.loc['매출액'], x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 매출액',height = 500 , width = 1000,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="71515803-f04e-4298-903b-00f3b61e64db" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71515803-f04e-4298-903b-00f3b61e64db")) {
#                     Plotly.newPlot(
#                         '71515803-f04e-4298-903b-00f3b61e64db',
# ...

# %%
data = df_compare.loc['플랫폼부문']

fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='플랫폼 부문 분기별 매출액', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='플랫폼 부문 분기별 매출액',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='플랫폼 부문 분기별 매출액 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="acd87b95-f4d3-4625-b370-86f67d6487b3" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("acd87b95-f4d3-4625-b370-86f67d6487b3")) {
#                     Plotly.newPlot(
#                         'acd87b95-f4d3-4625-b370-86f67d6487b3',
# ...

# %%
data = df_compare.loc['콘텐츠부문']

fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='콘텐츠 부문 분기별 매출액', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='콘텐츠 부문 분기별 매출액',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})

fig2.show()

fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='콘텐츠 부문 분기별 매출액 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3346c918-eb89-43ba-acd9-af150d211483" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3346c918-eb89-43ba-acd9-af150d211483")) {
#                     Plotly.newPlot(
#                         '3346c918-eb89-43ba-acd9-af150d211483',
# ...

# %% [markdown]
# #### 영업이익

# %%
# 영업이익 
data = df_compare.loc['영업이익']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 영업이익', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 영업이익',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 영업이익 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a2b06279-f6c2-45ef-aed3-3e3544aa49e9" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2b06279-f6c2-45ef-aed3-3e3544aa49e9")) {
#                     Plotly.newPlot(
#                         'a2b06279-f6c2-45ef-aed3-3e3544aa49e9',
# ...

# %%
# 영업이익률 
data = df_compare.loc['영업이익률(%)']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 영업이익률', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 영업이익률',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 영업이익률 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d2b70fe-341b-48eb-947e-9fb9e56873e9" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d2b70fe-341b-48eb-947e-9fb9e56873e9")) {
#                     Plotly.newPlot(
#                         '6d2b70fe-341b-48eb-947e-9fb9e56873e9',
# ...

# %% [markdown]
# #### 영업비용

# %%
# 영업비용 
data = df_compare.loc['영업비용']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 영업비용', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 영업비용',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 영업비용 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5c7ae16f-d432-4d86-9f3c-248c26d57528" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c7ae16f-d432-4d86-9f3c-248c26d57528")) {
#                     Plotly.newPlot(
#                         '5c7ae16f-d432-4d86-9f3c-248c26d57528',
# ...

# %%
# 마케팅비 
data = df_compare.loc['마케팅비']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 마케팅비', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 마케팅비',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 마케팅비 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cbeafdd-0628-4b2d-b65b-a1a53695a501" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cbeafdd-0628-4b2d-b65b-a1a53695a501")) {
#                     Plotly.newPlot(
#                         '6cbeafdd-0628-4b2d-b65b-a1a53695a501',
# ...

# %% [markdown]
# #### 당기순이익

# %%
# 당기순이익 
data = df_compare.loc['당기순이익']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 당기순이익', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 당기순이익',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 당기순이익 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b6168ed0-242e-4e78-a5ce-cb9d7b168f7e" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b6168ed0-242e-4e78-a5ce-cb9d7b168f7e")) {
#                     Plotly.newPlot(
#                         'b6168ed0-242e-4e78-a5ce-cb9d7b168f7e',
# ...

# %% [markdown]
# #### 조정 EBITDA

# %%
# 조정 EBITDA 
data = df_compare.loc['조정 EBITDA']

# 선그래프 
fig1 = px.line(data, x = 'quarter', y = 'value', color = '회사명', title='분기별 조정 EBITDA', height = 500  , width = 1200,
               color_discrete_map={'네이버':'green','카카오':'orange'})
fig1.update_xaxes(type='category')
fig1.update_traces(mode='markers+lines')
fig1.show()

# 막대 그래프 
fig2 = px.bar(data, x = 'quarter', y = 'value', color = '회사명',barmode = 'group' , title='분기별 조정 EBITDA',height = 500 , width = 1200,
              color_discrete_map={'네이버':'green','카카오':'orange'})
fig2.show()

# 각 분기별 비교 
fig3 = px.bar(data, x = '회사명', y = 'value', facet_col = 'quarter', facet_col_wrap = 4 ,  title='분기별 조정 EBITDA 비교', color = '회사명', 
              height = 700 , width = 1200, color_discrete_map={'네이버':'green','카카오':'orange'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2cd25df1-3543-4ba3-a920-738c40cffbd3" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2cd25df1-3543-4ba3-a920-738c40cffbd3")) {
#                     Plotly.newPlot(
#                         '2cd25df1-3543-4ba3-a920-738c40cffbd3',
# ...
